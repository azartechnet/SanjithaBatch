# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skew
# Out:
# C:\Users\azart\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
#Load dataset
titanic=sns.load_dataset('titanic')

print(titanic.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Step 2 Calculate Skewness
#calculate the skewness for numerical columns in the dataset
#selete numerical columns

numerical_columns=titanic.select_dtypes(include=['float64','int64']).columns;

# %%
numerical_columns
# Out:
# Index(['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare'], dtype='object')

# %%
#calculate skewness for each numbericak columns;
skewness_values=titanic[numerical_columns].apply(lambda x: skew(x.dropna()))

print(skewness_values)
# Out:
# survived    0.477717
# pclass     -0.629486
# age         0.388290
# sibsp       3.689128
# parch       2.744487
# fare        4.779253
# dtype: float64

# %%
# Step 3: Interpret Skewness
# Interpret the skewness values:

# Skewness > 0: Data is positively skewed (right-skewed)
# Skewness < 0: Data is negatively skewed (left-skewed)
# Skewness ≈ 0: Data is symmetric

# %%
#Step 4 visualize skewness

# %%
for column in numerical_columns:
    plt.figure(figsize=(10,6))
    sns.histplot(titanic[column].dropna(),kde=True)
    plt.title("Distribution")
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# C:\Users\azart\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\azart\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\azart\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\azart\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\azart\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\azart\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Kurtosis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import kurtosis
# Out:
# C:\Users\azart\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
#Load dataset
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Step 2 Calculate kurtosis
numerical_columns=titanic.select_dtypes(include=['float64','int64']).columns

# %%
numerical_columns
# Out:
# Index(['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare'], dtype='object')

# %%
kurtosis_values=titanic[numerical_columns].apply(lambda x:kurtosis(x.dropna()))

# %%
kurtosis_values
# Out:
# survived    -1.771786
# pclass      -1.279570
# age          0.168637
# sibsp       17.773512
# parch        9.716613
# fare        33.204289
# dtype: float64

# %%
for column in numerical_columns:
    plt.figure(figsize=(10,6))
    sns.histplot(titanic[column].dropna(),kde=True)
    plt.title("Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# C:\Users\azart\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\azart\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\azart\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\azart\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\azart\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\azart\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Probability theory is a fundamental field of mathematics
#that deals with the likelihood of events occurring. Here are some key concepts 
#and examples of algorithms related to probability theory:

# 1. Basic Probability
# Example: Probability of a single event occurring.

# %%
import random

# %%
sample_space=[10,20,3,4,5,6]

#Event : Rolling a 3
event=[3]

#probability of the event

probability=len(event)/len(sample_space)

print(f'Probality or rolling a 3:{probability}')
# Out:
# Probality or rolling a 3:0.16666666666666666

# %%
# Example: Probability of drawing an ace given that the card is a spade from a deck of cards

# Define the deck of cards
deck = [(rank, suit) for rank in range(1, 14) for suit in ['hearts', 'diamonds', 'clubs', 'spades']]

# Event A: Drawing an ace
event_A = [card for card in deck if card[0] == 1]

# Event B: Drawing a spade
event_B = [card for card in deck if card[1] == 'spades']

# Joint event A and B: Drawing an ace of spades
event_A_and_B = [card for card in event_A if card[1] == 'spades']

# Calculate probabilities
P_A_and_B = len(event_A_and_B) / len(deck)
P_B = len(event_B) / len(deck)
P_A_given_B = P_A_and_B / P_B

print(f'Probability of drawing an ace given that the card is a spade: {P_A_given_B}')
# Out:
# Probability of drawing an ace given that the card is a spade: 0.07692307692307693

# %%
#Central limit theorem with sample mean

# %%
import numpy as np

# %%
#Generate a population with a non-normal distribution
population=np.random.exponential(scale=2,size=10000)
#Number of Samples and Sample size
n_samples=1000
sample_size=100

# %%
population
# Out:
# array([2.28510023, 0.902804  , 0.43476658, ..., 1.70467394, 0.68507602,
#        1.44549529])

# %%
#Draw samples and calculate sample means
sample_means=[np.mean(np.random.choice(population,size=sample_size)) for _ in range(n_samples)]

# %%
sample_means
# Out:
# [1.0202279380920534,
#  1.0642382706950948,
#  1.0394405744510609,
#  0.9127896448842125,
#  0.9435567017307198,
#  0.9256900224351274,
#  0.9646150526892313,
#  1.0091021016083774,
#  1.048120587996219,
#  0.8869404720775771,
#  1.0671103244392315,
#  1.0023056627200875,
#  0.8668009416751218,
#  1.0796916232637048,
#  1.0746220480030244,
#  1.0427103680437826,
#  1.0528024044476745,
#  1.1084124962591706,
#  0.940048201586705,
#  0.9879416832621498,
#  0.8871999715481124,
#  0.9917181875353578,
#  0.9571796176880166,
#  1.0038094548163452,
#  0.8471206763451046,
#  1.1587525686191404,
#  1.0575287677947969,
#  1.025180327241895,
#  0.8419440309978303,
#  0.9976131182834354,
#  1.0023606593110437,
#  1.0032554999548373,
#  1.0246134033799459,
#  0.8862510990080896,
#  1.054934704608662,
#  1.214797920695829,
#  0.9782993830921248,
#  0.9365226952312555,
#  0.9178989316957302,
#  1.0081031905640152,
#  1.0133806817307838,
#  0.9661424793090617,
#  0.9519795423548385,
#  0.9181124633512928,
#  1.0441300506584499,
#  1.0642568707120943,
#  0.9894971540325835,
#  0.7896631031964739,
#  1.1533167020328712,
#  1.0690060650182054,
#  0.9839823295537972,
#  0.8386194936093613,
#  0.9362668662614803,
#  0.9089397272367624,
#  0.9812395400106229,
#  0.8948372851319132,
#  0.9020084325252462,
#  1.0709333266424026,
#  1.049306108599806,
#  0.8571192488695744,
#  1.0415293527184297,
#  1.045481297177441,
#  1.0156084988322072,
#  0.9811616765385408,
#  0.9045848548871812,
#  1.0342548892199264,
#  0.9201201495826488,
#  0.8697683337358284,
#  1.0069353576594229,
#  1.0142135645730408,
#  1.0548247286052526,
#  1.008821475721117,
#  0.8834492002337597,
#  0.8359040792016623,
#  1.000315396973646,
#  1.1827658260772962,
#  1.0378593216917888,
#  0.9962314845547382,
#  1.1625278429486048,
#  0.963581363146499,
#  1.1236347234643125,
#  0.965762255450992,
#  1.1564412899292558,
#  1.0909284349150246,
#  1.0721658529017268,
#  1.085121949082602,
#  1.0083858305733409,
#  0.9527874881544101,
#  0.9748627720439497,
#  1.0738146521876768,
#  0.9702928861719513,
#  1.1236100146012262,
#  1.0937731973687597,
#  0.8720019166564025,
#  1.0509044041065123,
#  0.991180977740103,
#  1.0208605060308766,
#  0.9830161987165777,
#  1.054641635741299,
#  0.8261963730663422,
#  0.893689057650132,
#  1.1174600520222477,
#  0.9587780446673313,
#  1.04431537996435,
#  0.9082013256668509,
#  1.0935730461238038,
#  0.7920987875139306,
#  1.0245201282998002,
#  0.8938291676266281,
#  0.9573698984699042,
#  1.0870295691138934,
#  0.8792704278918445,
#  1.1298748776622658,
#  0.8489523596834322,
#  1.0172769885310426,
#  0.9591752618898414,
#  0.9203379724680615,
#  1.0586104836434207,
#  0.8959882905500437,
#  1.003778058367181,
#  0.8552298501456845,
#  1.1264033206507733,
#  1.0724634704135487,
#  0.973146679601317,
#  0.9988884255563021,
#  1.0563451614791033,
#  0.9160301216368981,
#  1.0513560468752603,
#  1.2579367099858951,
#  0.9721737103413923,
#  0.9459925719667847,
#  0.8237922187236235,
#  1.0116549908829744,
#  1.16674311127108,
#  1.0057858283543666,
#  0.9236289499962131,
#  0.9759964170593254,
#  1.1763723956139944,
#  1.1346446808655606,
#  0.9367926598443286,
#  1.0586632227262023,
#  0.97058963523238,
#  1.189356934256956,
#  0.9809346215841569,
#  0.8538679675540467,
#  1.0771303584654393,
#  1.0045251234905888,
#  1.0379750791912314,
#  1.1662497662472706,
#  1.2209144610344114,
#  0.9271148233273585,
#  1.0400381182626608,
#  0.9757271060080002,
#  0.9450610524698171,
#  1.0071256039976542,
#  1.339418165641538,
#  1.1588433852085411,
#  0.9421204712053612,
#  1.1644202568571107,
#  0.963858415991954,
#  0.9825018891808027,
#  0.9490295224871477,
#  1.0700687141918184,
#  1.0570436800464789,
#  1.0611583972760585,
#  1.0737679003350078,
#  1.0476793105750524,
#  0.9220222174203427,
#  1.0483370693877583,
#  1.0166234124776006,
#  0.9503202199228191,
#  1.097131367139499,
#  1.0431604903927927,
#  0.9403945757991135,
#  1.1348686539660857,
#  1.0825672497446794,
#  0.9434717071680148,
#  1.0936575350683566,
#  1.0304516151461995,
#  1.1373424224199824,
#  0.938771619027651,
#  1.105113402483277,
#  0.9174083271110739,
#  1.0415188603652084,
#  1.0041008063437082,
#  1.1483268279650387,
#  1.0615451026475013,
#  1.0964509335844808,
#  1.064717593086176,
#  0.8968092914059028,
#  0.9898503633988627,
#  0.9342082879819703,
#  0.8904373975923027,
#  0.9175875832493167,
#  0.9181804037039893,
#  0.9607280425602772,
#  0.938598704340792,
#  0.9964370255980579,
#  0.8864320436077509,
#  0.7904651337362177,
#  1.1005283306278404,
#  1.1618302017795206,
#  1.0505235095484544,
#  1.1064741525366093,
#  1.1329257757485898,
#  0.8567387354112661,
#  1.023886597140221,
#  1.0772021317962284,
#  0.9186584535977367,
#  0.9464220647805631,
#  0.9204236934887962,
#  0.9288733404399211,
#  1.0665712218360799,
#  0.9909009192035058,
#  1.0153428390836492,
#  1.0935742507089803,
#  0.8325720862884017,
#  1.0702565767900065,
#  1.0900143580514898,
#  1.2062013058015801,
#  0.8706034938296986,
#  0.9103714963240808,
#  0.9321437591637514,
#  0.9749426622956845,
#  0.8286953700306665,
#  1.0533249546853627,
#  1.0082992013679695,
#  1.0827970071443525,
#  0.9321049538396312,
#  1.0502080183559253,
#  0.9687364727448196,
#  0.9682061058647895,
#  0.8803133965403215,
#  1.0764607261813859,
#  0.9510619403191146,
#  1.0101163174115333,
#  1.023675615816675,
#  1.1749051354903128,
#  0.9159776197627061,
#  1.1100394788528394,
#  1.0454359114214338,
#  0.8801913249343505,
#  1.0247967606642814,
#  0.9577089907582577,
#  0.9147399067139057,
#  1.1165029278444942,
#  1.046259788439215,
#  1.0105894194956355,
#  1.0339849205815992,
#  1.1099845677498348,
#  0.898809215218829,
#  1.3289746664042545,
#  0.9271859786146024,
#  0.8625454632409282,
#  1.0504215215139334,
#  1.0730809679075437,
#  1.0747627019141706,
#  1.0086120214695264,
#  1.0946023902730324,
#  0.8120384046418216,
#  1.0617817656160435,
#  0.8481846642017371,
#  0.956943084442634,
#  1.0071130852859096,
#  0.896420862356193,
#  1.0738422888272634,
#  0.942315088533998,
#  0.9321706682907709,
#  1.158879798892688,
#  1.0527189860631436,
#  1.0806845197211303,
#  0.9615368388141432,
#  1.0985933839346882,
#  0.9863687680642506,
#  1.1012355027315537,
#  1.168717026114322,
#  0.9681350821246592,
#  0.9675365858310827,
#  1.0162897049527162,
#  1.045557803181269,
#  1.0614629892264384,
#  1.0225019895899035,
#  1.0356282242951143,
#  0.9409064313981805,
#  1.007646983708668,
#  1.1131190081664535,
#  0.7792600315756489,
#  0.8911012788308686,
#  1.0249730400492973,
#  0.9743272333460559,
#  1.0799355790266825,
#  1.017126534779698,
#  0.9412874348835955,
#  0.9394007338516462,
#  1.0996808270995628,
#  1.0879422679444533,
#  1.1837935571500116,
#  0.9813056024890892,
#  0.9392371738292211,
#  0.8367751920170013,
#  0.9403894172233401,
#  1.2253055939829596,
#  1.0139030749663789,
#  1.060776318256798,
#  1.194296447826444,
#  0.9195552222787055,
#  1.1048752286925394,
#  0.91700363704,
#  0.9968440954717758,
#  1.0591824008620285,
#  1.0769415882329074,
#  0.9936862739829884,
#  1.0920802390598225,
#  0.9832982173493603,
#  1.0556995748266027,
#  1.02169612223281,
#  0.9202626608757847,
#  1.0225200192075992,
#  0.954677752552553,
#  0.9331479477267124,
#  1.1636185745317702,
#  1.0913716000060945,
#  0.9328647886601732,
#  1.1017524178522873,
#  1.02407331932289,
#  0.9085293689721755,
#  1.1354284555962537,
#  0.8354332704518508,
#  0.9196003365005657,
#  0.8714404285839366,
#  1.1347290113603348,
#  1.1145488087461881,
#  0.8985866557261492,
#  1.0193343646752222,
#  1.0202336334513147,
#  1.0485827251265731,
#  1.0577914091146796,
#  1.0035854828903055,
#  1.053647209946417,
#  0.8483966297668712,
#  0.8482654618753785,
#  1.0782035940477446,
#  1.0879021819534167,
#  1.0265358677970142,
#  0.9627404964630455,
#  0.9841585476587177,
#  1.197894368990369,
#  1.1075843069004996,
#  1.0580751912675699,
#  1.0997229680160636,
#  0.8376169511778158,
#  1.146240102022512,
#  0.8525661216602372,
#  0.9178913521478926,
#  1.1225319116749242,
#  0.8936826768021259,
#  1.1134420421782179,
#  0.9566393425395496,
#  0.9462077646079837,
#  0.8608613840245503,
#  0.9074589992350144,
#  0.991430624083225,
#  1.000418535854031,
#  0.8733670541873407,
#  1.1114498319719588]
